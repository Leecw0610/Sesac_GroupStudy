# %%
import pandas as pd
import numpy as np

# %%
demen = pd.read_csv('demensia20220310.csv', encoding='euc-kr')

# %%
demen

# %%
demen.head(10)  #변수 항목별 단위 ?? //유병률

#자료의 구조 파악 ; 시점 / 행정구역(시도) / 행정구역(기초) / 연령대별(Groupby를 해놓은 자료)
#어떤 병의 유병률은 그 구간 노인수에서 그 병을 가지고 있는 사람들의 백분율
#<최경도.경도.중등도.중증>은 모두 치매 환자수에서 구간을 경도별 재구간화 시킨 값
#치매환자수 = 알츠하이머환자수 + 혈관성치매환자수 + 기타환자 환자수
#경도인지장애 = 치매환자에 분류되진 않지만 미미하게 치매의 증상을 보이는? (전조?) 환자로 따로 분류

# %%
demen.columns

# %%
demen.info()

# %%
#자료의 구조 파악 ; 시점 / 행정구역(시도) / 행정구역(기초) / 연령대별(Groupby를 해놓은 자료)
#어떤 병의 유병률은 그 구간 노인수에서 그 병을 가지고 있는 사람들의 백분율
#<최경도.경도.중등도.중증>은 모두 치매 환자수에서 구간을 경도별 재구간화 시킨 값
#치매환자수 = 알츠하이머환자수 + 혈관성치매환자수 + 기타환자 환자수
#경도인지장애 = 치매환자에 분류되진 않지만 미미하게 치매의 증상을 보이는? (전조?) 환자로 따로 분류

# %% [markdown]
# 1. 행정구역(시도)별 과 행정구역(기초)별 합쳐 파생변수를 시도구별로 만드시오.
# (단, 이름이 정상적이지 않다면 변경하시오.
# ex)전국전국 -> 전국 / 제주특별자치도서귀포시 -> 제주특별자치도 서귀포시)

# %%
#데이터 상 두개의 항목값이 겹치는 경우에만 이름이 정상적이지 않음을 확인.
#따라서 두개의 항목 값을 문자열 합으로 합치되, 두항목값이 완전히 같은 경우에는 한번만 출력!<np.where>활용

# %%
demen['행정구역(시도)별']

# %%
demen['행정구역(기초)별']

# %%
len(demen)

# %%
demen['행정구역(기초)별'][80]

# %%
type(demen['행정구역(기초)별'])

# %%
demen

# %%
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
for i in tqdm(range (len(demen))):
    
    if demen['행정구역(시도)별'][i] == demen['행정구역(기초)별'][i] :
        demen['시도구별'][i] = demen['행정구역(시도)별'][i]
    else :
        demen['시도구별'][i] = demen['행정구역(시도)별'][i] + ' ' + demen['행정구역(기초)별'][i]
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 13740/13740 [01:24<00:00, 162.30it/s]

# %%
demen
# Out:
#          시점 행정구역(시도)별 행정구역(기초)별  성별     연령별      노인인구수      치매환자수  치매환자유병률  \
# 0      2020        전국        전국  전체  60~64세  3804709.5   23350.26     0.61
# 1      2020        전국        전국  전체  65~69세  2635592.0   36620.52     1.39
# 2      2020        전국        전국  전체  70~74세  2000708.5   77236.58     3.86
# 3      2020        전국        전국  전체  75~79세  1602662.5  189626.57    11.83
# 4      2020        전국        전국  전체  80~84세  1110911.5  232892.50    20.96
# ...     ...       ...       ...  ..     ...        ...        ...      ...
# 13735  2021   제주특별자치도      서귀포시   여  75~79세     3873.0     532.92    13.76
# 13736  2021   제주특별자치도      서귀포시   여  80~84세     3345.0     778.05    23.26
# 13737  2021   제주특별자치도      서귀포시   여   85세이상     3439.5    1134.00    32.97
# 13738  2021   제주특별자치도      서귀포시   여   60세이상    27760.0    2645.05     9.53
# 13739  2021   제주특별자치도      서귀포시   여   65세이상    20525.5    2637.09    12.85
#
#          최경도 환자     경도 환자  ...     중증 환자  알츠하이머 환자수  알츠하이머 환자유병률  혈관성치매 환자수  \
# 0       4062.95   9667.01  ...   3619.29       0.00         0.00   23350.26
# 1       6371.97  15160.90  ...   5676.18   34204.14         1.30       0.00
# 2      13439.16  31975.94  ...  11971.67   74101.52         3.70    1868.56
# 3      32995.02  78505.40  ...  29392.12   79081.82         4.93   36835.05
# 4      40523.30  96417.50  ...  36098.34  182257.11        16.41    8518.04
# ...         ...       ...  ...       ...        ...          ...        ...
# 13735     92.73    220.63  ...     82.60     247.48         6.39      32.15
# 13736    135.38    322.11  ...    120.60     704.12        21.05      11.71
# 13737    197.32    469.48  ...    175.77     973.03        28.29      78.42
# 13738    460.24   1095.05  ...    409.98    2111.89         7.61     130.23
# 13739    458.85   1091.76  ...    408.75    2111.89        10.29     122.27
#
#        혈관성치매 환자유병률  기타 환자환자수  기타 환자유병률  경도인지장애 환자수  경도인지장애 환자유병률          시도구별
# 0             0.61      0.00      0.00   568975.71         14.95            전국
# 1             0.00   2416.38      0.09   472079.05         17.91            전국
# 2             0.09   1279.71      0.06   432263.10         21.61            전국
# 3             2.30  73617.65      4.59   238681.35         14.89            전국
# 4             0.77  42047.60      3.78   530714.37         47.77            전국
# ...            ...       ...       ...         ...           ...           ...
# 13735         0.83    252.91      6.53      807.83         20.86  제주특별자치도 서귀포시
# 13736         0.35     61.88      1.85     1540.65         46.06  제주특별자치도 서귀포시
# 13737         2.28     82.20      2.39      799.73         23.25  제주특별자치도 서귀포시
# 13738         0.47    402.31      1.45     5688.87         20.49  제주특별자치도 서귀포시
# 13739         0.60    402.31      1.96     5371.43         26.17  제주특별자치도 서귀포시
#
# [13740 rows x 21 columns]

# %%
demen['시도구별']

# %%
type(demen['행정구역(기초)별'][0])

# %%
demen['행정구역(시도)별'][i]

# %%
demen['행정구역(시도)별'][150]

# %%
demen['행정구역(기초)별'][150]

# %% [markdown]
# 2. 사람의 수를 나타내는 칼럼에 소수점이 포함되어 있는 소수점을 없애어 나타내시오.
# ex) (노인인구수, 중증환자, ... 등)

# %%
#단위 필요? 단위가 있다면 항목값에 단위를 곱해주고 그 값들을 원래 값에 대체 (replace함수필요)

# %%
int(demen['노인인구수'][0]) #노인인구수의 데이터 하나하나씩을 int화 하여야한다.(지금은 float)
# Out:
# 3804709

# %%
demen['노인인구수']
# Out:
# 0        3804709.5
# 1        2635592.0
# 2        2000708.5
# 3        1602662.5
# 4        1110911.5
#            ...
# 13735       3873.0
# 13736       3345.0
# 13737       3439.5
# 13738      27760.0
# 13739      20525.5
# Name: 노인인구수, Length: 13740, dtype: float64

# %%
len(demen)
# Out:
# 13740

# %%
demen['노인인구수'][0]
# Out:
# 3804709.5

# %%
demen['노인인구수'][0].astype(float)
# Out:
# 3804709.5

# %% [raw]
# demen['노인인구수'] = demen['노인인구수'] * 100

# %% [raw]
# demen['노인인구수']

# %% [raw]
# for i in range (len(demen)):
#     demen['노인인구수1'] = demen.replace(demen['노인인구수'][i] , ((float(demen['노인인구수'][i])) *(100)))
#     i += 1

# %%
list(demen.columns)
# Out:
# ['시점',
#  '행정구역(시도)별',
#  '행정구역(기초)별',
#  '성별',
#  '연령별',
#  '노인인구수',
#  '치매환자수',
#  '치매환자유병률',
#  '최경도 환자',
#  '경도 환자',
#  '중등도 환자',
#  '중증 환자',
#  '알츠하이머 환자수',
#  '알츠하이머 환자유병률',
#  '혈관성치매 환자수',
#  '혈관성치매 환자유병률',
#  '기타 환자환자수',
#  '기타 환자유병률',
#  '경도인지장애 환자수',
#  '경도인지장애 환자유병률',
#  '시도구별']

# %%
#### demen['치매환자수'] = demen['치매환자수'] * 100

# %%
demen1 = demen.drop(['시점','행정구역(시도)별','행정구역(기초)별','성별','연령별','치매환자유병률',\
                    '알츠하이머 환자유병률', '혈관성치매 환자유병률', '기타 환자유병률', '경도인지장애 환자유병률' ], axis =1)

# %%
demen1
# Out:
#            노인인구수      치매환자수    최경도 환자     경도 환자    중등도 환자     중증 환자  \
# 0      3804709.5   23350.26   4062.95   9667.01   6001.02   3619.29
# 1      2635592.0   36620.52   6371.97  15160.90   9411.47   5676.18
# 2      2000708.5   77236.58  13439.16  31975.94  19849.80  11971.67
# 3      1602662.5  189626.57  32995.02  78505.40  48734.03  29392.12
# 4      1110911.5  232892.50  40523.30  96417.50  59853.37  36098.34
# ...          ...        ...       ...       ...       ...       ...
# 13735     3873.0     532.92     92.73    220.63    136.96     82.60
# 13736     3345.0     778.05    135.38    322.11    199.96    120.60
# 13737     3439.5    1134.00    197.32    469.48    291.44    175.77
# 13738    27760.0    2645.05    460.24   1095.05    679.78    409.98
# 13739    20525.5    2637.09    458.85   1091.76    677.73    408.75
#
#        알츠하이머 환자수  혈관성치매 환자수  기타 환자환자수  경도인지장애 환자수          시도구별
# 0           0.00   23350.26      0.00   568975.71            전국
# 1       34204.14       0.00   2416.38   472079.05            전국
# 2       74101.52    1868.56   1279.71   432263.10            전국
# 3       79081.82   36835.05  73617.65   238681.35            전국
# 4      182257.11    8518.04  42047.60   530714.37            전국
# ...          ...        ...       ...         ...           ...
# 13735     247.48      32.15    252.91      807.83  제주특별자치도 서귀포시
# 13736     704.12      11.71     61.88     1540.65  제주특별자치도 서귀포시
# 13737     973.03      78.42     82.20      799.73  제주특별자치도 서귀포시
# 13738    2111.89     130.23    402.31     5688.87  제주특별자치도 서귀포시
# 13739    2111.89     122.27    402.31     5371.43  제주특별자치도 서귀포시
#
# [13740 rows x 11 columns]

# %%
list(demen1.columns)
# Out:
# ['노인인구수',
#  '치매환자수',
#  '최경도 환자',
#  '경도 환자',
#  '중등도 환자',
#  '중증 환자',
#  '알츠하이머 환자수',
#  '혈관성치매 환자수',
#  '기타 환자환자수',
#  '경도인지장애 환자수',
#  '시도구별']

# %%
co = list(demen1.columns)
for i in co :
    demen[i] = (demen[i] * 100).astype(int)

# %%
demen

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# 1. 행정구역(시도)별 과 행정구역(기초)별 합쳐 파생변수를 시도구별로 만드시오.
# (단, 이름이 정상적이지 않다면 변경하시오.
# ex)전국전국 -> 전국 / 제주특별자치도서귀포시 -> 제주특별자치도 서귀포시)

# %%
demen.head(5)
# Out:
#      시점 행정구역(시도)별 행정구역(기초)별  성별     연령별      노인인구수      치매환자수  치매환자유병률  \
# 0  2020        전국        전국  전체  60~64세  3804709.5   23350.26     0.61
# 1  2020        전국        전국  전체  65~69세  2635592.0   36620.52     1.39
# 2  2020        전국        전국  전체  70~74세  2000708.5   77236.58     3.86
# 3  2020        전국        전국  전체  75~79세  1602662.5  189626.57    11.83
# 4  2020        전국        전국  전체  80~84세  1110911.5  232892.50    20.96
#
#      최경도 환자     경도 환자    중등도 환자     중증 환자  알츠하이머 환자수  알츠하이머 환자유병률  혈관성치매 환자수  \
# 0   4062.95   9667.01   6001.02   3619.29       0.00         0.00   23350.26
# 1   6371.97  15160.90   9411.47   5676.18   34204.14         1.30       0.00
# 2  13439.16  31975.94  19849.80  11971.67   74101.52         3.70    1868.56
# 3  32995.02  78505.40  48734.03  29392.12   79081.82         4.93   36835.05
# 4  40523.30  96417.50  59853.37  36098.34  182257.11        16.41    8518.04
#
#    혈관성치매 환자유병률  기타 환자환자수  기타 환자유병률  경도인지장애 환자수  경도인지장애 환자유병률
# 0         0.61      0.00      0.00   568975.71         14.95
# 1         0.00   2416.38      0.09   472079.05         17.91
# 2         0.09   1279.71      0.06   432263.10         21.61
# 3         2.30  73617.65      4.59   238681.35         14.89
# 4         0.77  42047.60      3.78   530714.37         47.77

# %%
demen['시도구별'] = np.where(demen['행정구역(시도)별'] == demen['행정구역(기초)별'], demen['행정구역(시도)별'], demen['행정구역(시도)별'] +' '+ demen['행정구역(기초)별'])

# %%
demen['시도구별']
# Out:
# 0                  전국
# 1                  전국
# 2                  전국
# 3                  전국
# 4                  전국
#              ...
# 13735    제주특별자치도 서귀포시
# 13736    제주특별자치도 서귀포시
# 13737    제주특별자치도 서귀포시
# 13738    제주특별자치도 서귀포시
# 13739    제주특별자치도 서귀포시
# Name: 시도구별, Length: 13740, dtype: object

# %%
demen
# Out:
#          시점 행정구역(시도)별 행정구역(기초)별  성별     연령별      노인인구수      치매환자수  치매환자유병률  \
# 0      2020        전국        전국  전체  60~64세  3804709.5   23350.26     0.61
# 1      2020        전국        전국  전체  65~69세  2635592.0   36620.52     1.39
# 2      2020        전국        전국  전체  70~74세  2000708.5   77236.58     3.86
# 3      2020        전국        전국  전체  75~79세  1602662.5  189626.57    11.83
# 4      2020        전국        전국  전체  80~84세  1110911.5  232892.50    20.96
# ...     ...       ...       ...  ..     ...        ...        ...      ...
# 13735  2021   제주특별자치도      서귀포시   여  75~79세     3873.0     532.92    13.76
# 13736  2021   제주특별자치도      서귀포시   여  80~84세     3345.0     778.05    23.26
# 13737  2021   제주특별자치도      서귀포시   여   85세이상     3439.5    1134.00    32.97
# 13738  2021   제주특별자치도      서귀포시   여   60세이상    27760.0    2645.05     9.53
# 13739  2021   제주특별자치도      서귀포시   여   65세이상    20525.5    2637.09    12.85
#
#          최경도 환자     경도 환자  ...     중증 환자  알츠하이머 환자수  알츠하이머 환자유병률  혈관성치매 환자수  \
# 0       4062.95   9667.01  ...   3619.29       0.00         0.00   23350.26
# 1       6371.97  15160.90  ...   5676.18   34204.14         1.30       0.00
# 2      13439.16  31975.94  ...  11971.67   74101.52         3.70    1868.56
# 3      32995.02  78505.40  ...  29392.12   79081.82         4.93   36835.05
# 4      40523.30  96417.50  ...  36098.34  182257.11        16.41    8518.04
# ...         ...       ...  ...       ...        ...          ...        ...
# 13735     92.73    220.63  ...     82.60     247.48         6.39      32.15
# 13736    135.38    322.11  ...    120.60     704.12        21.05      11.71
# 13737    197.32    469.48  ...    175.77     973.03        28.29      78.42
# 13738    460.24   1095.05  ...    409.98    2111.89         7.61     130.23
# 13739    458.85   1091.76  ...    408.75    2111.89        10.29     122.27
#
#        혈관성치매 환자유병률  기타 환자환자수  기타 환자유병률  경도인지장애 환자수  경도인지장애 환자유병률          시도구별
# 0             0.61      0.00      0.00   568975.71         14.95            전국
# 1             0.00   2416.38      0.09   472079.05         17.91            전국
# 2             0.09   1279.71      0.06   432263.10         21.61            전국
# 3             2.30  73617.65      4.59   238681.35         14.89            전국
# 4             0.77  42047.60      3.78   530714.37         47.77            전국
# ...            ...       ...       ...         ...           ...           ...
# 13735         0.83    252.91      6.53      807.83         20.86  제주특별자치도 서귀포시
# 13736         0.35     61.88      1.85     1540.65         46.06  제주특별자치도 서귀포시
# 13737         2.28     82.20      2.39      799.73         23.25  제주특별자치도 서귀포시
# 13738         0.47    402.31      1.45     5688.87         20.49  제주특별자치도 서귀포시
# 13739         0.60    402.31      1.96     5371.43         26.17  제주특별자치도 서귀포시
#
# [13740 rows x 21 columns]

# %% [raw]
# 2. 사람의 수를 나타내는 칼럼에 소수점이 포함되어 있는 소수점을 없애어 나타내시오.
# ex) (노인인구수, 중증환자, ... 등)

# %% [raw]
# 2-1) 사람의 수를 나타내는 칼럼을 뽑고

# %%
demen.columns
# Out:
# Index(['시점', '행정구역(시도)별', '행정구역(기초)별', '성별', '연령별', '노인인구수', '치매환자수',
#        '치매환자유병률', '최경도 환자', '경도 환자', '중등도 환자', '중증 환자', '알츠하이머 환자수',
#        '알츠하이머 환자유병률', '혈관성치매 환자수', '혈관성치매 환자유병률', '기타 환자환자수', '기타 환자유병률',
#        '경도인지장애 환자수', '경도인지장애 환자유병률', '시도구별'],
#       dtype='object')

# %%
demen.dtypes
# Out:
# 시점                int64
# 행정구역(시도)별        object
# 행정구역(기초)별        object
# 성별               object
# 연령별              object
# 노인인구수           float64
# 치매환자수           float64
# 치매환자유병률         float64
# 최경도 환자          float64
# 경도 환자           float64
# 중등도 환자          float64
# 중증 환자           float64
# 알츠하이머 환자수       float64
# 알츠하이머 환자유병률     float64
# 혈관성치매 환자수       float64
# 혈관성치매 환자유병률     float64
# 기타 환자환자수        float64
# 기타 환자유병률        float64
# 경도인지장애 환자수      float64
# 경도인지장애 환자유병률    float64
# 시도구별             object
# dtype: object

# %%
demen
# Out:
#          시점 행정구역(시도)별 행정구역(기초)별  성별     연령별      노인인구수      치매환자수  치매환자유병률  \
# 0      2020        전국        전국  전체  60~64세  3804709.5   23350.26     0.61
# 1      2020        전국        전국  전체  65~69세  2635592.0   36620.52     1.39
# 2      2020        전국        전국  전체  70~74세  2000708.5   77236.58     3.86
# 3      2020        전국        전국  전체  75~79세  1602662.5  189626.57    11.83
# 4      2020        전국        전국  전체  80~84세  1110911.5  232892.50    20.96
# ...     ...       ...       ...  ..     ...        ...        ...      ...
# 13735  2021   제주특별자치도      서귀포시   여  75~79세     3873.0     532.92    13.76
# 13736  2021   제주특별자치도      서귀포시   여  80~84세     3345.0     778.05    23.26
# 13737  2021   제주특별자치도      서귀포시   여   85세이상     3439.5    1134.00    32.97
# 13738  2021   제주특별자치도      서귀포시   여   60세이상    27760.0    2645.05     9.53
# 13739  2021   제주특별자치도      서귀포시   여   65세이상    20525.5    2637.09    12.85
#
#          최경도 환자     경도 환자  ...     중증 환자  알츠하이머 환자수  알츠하이머 환자유병률  혈관성치매 환자수  \
# 0       4062.95   9667.01  ...   3619.29       0.00         0.00   23350.26
# 1       6371.97  15160.90  ...   5676.18   34204.14         1.30       0.00
# 2      13439.16  31975.94  ...  11971.67   74101.52         3.70    1868.56
# 3      32995.02  78505.40  ...  29392.12   79081.82         4.93   36835.05
# 4      40523.30  96417.50  ...  36098.34  182257.11        16.41    8518.04
# ...         ...       ...  ...       ...        ...          ...        ...
# 13735     92.73    220.63  ...     82.60     247.48         6.39      32.15
# 13736    135.38    322.11  ...    120.60     704.12        21.05      11.71
# 13737    197.32    469.48  ...    175.77     973.03        28.29      78.42
# 13738    460.24   1095.05  ...    409.98    2111.89         7.61     130.23
# 13739    458.85   1091.76  ...    408.75    2111.89        10.29     122.27
#
#        혈관성치매 환자유병률  기타 환자환자수  기타 환자유병률  경도인지장애 환자수  경도인지장애 환자유병률          시도구별
# 0             0.61      0.00      0.00   568975.71         14.95            전국
# 1             0.00   2416.38      0.09   472079.05         17.91            전국
# 2             0.09   1279.71      0.06   432263.10         21.61            전국
# 3             2.30  73617.65      4.59   238681.35         14.89            전국
# 4             0.77  42047.60      3.78   530714.37         47.77            전국
# ...            ...       ...       ...         ...           ...           ...
# 13735         0.83    252.91      6.53      807.83         20.86  제주특별자치도 서귀포시
# 13736         0.35     61.88      1.85     1540.65         46.06  제주특별자치도 서귀포시
# 13737         2.28     82.20      2.39      799.73         23.25  제주특별자치도 서귀포시
# 13738         0.47    402.31      1.45     5688.87         20.49  제주특별자치도 서귀포시
# 13739         0.60    402.31      1.96     5371.43         26.17  제주특별자치도 서귀포시
#
# [13740 rows x 21 columns]

# %%
#deman.columns
demen.columns = demen.columns.astype(str)
 
for i in demen.columns :  #demen의 칼럼 리스트 내에서 항목을 하나씩 추출하고,
    print (i)
    if i.str.contains('수') :
        print(i)
        #demen1 = demen['i'].str.contains('률')
   # else :
      #  pass
# Out:
# 시점
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [47], in <cell line: 4>()
#       4 for i in demen.columns :  #demen의 칼럼 리스트 내에서 항목을 하나씩 추출하고,
#       5     print (i)
# ----> 6     if i.str.contains('수') :
#       7         print(i)
#
# AttributeError: 'str' object has no attribute 'str'

# %%
demen.columns
# Out:
# Index(['시점', '행정구역(시도)별', '행정구역(기초)별', '성별', '연령별', '노인인구수', '치매환자수',
#        '치매환자유병률', '최경도 환자', '경도 환자', '중등도 환자', '중증 환자', '알츠하이머 환자수',
#        '알츠하이머 환자유병률', '혈관성치매 환자수', '혈관성치매 환자유병률', '기타 환자환자수', '기타 환자유병률',
#        '경도인지장애 환자수', '경도인지장애 환자유병률', '시도구별'],
#       dtype='object')

# %%
demen.columns[1][-1]
# Out:
# '별'

# %% [raw]
# 2-2) 소수점을 정수화

# %%
demen
# Out:
#          시점 행정구역(시도)별 행정구역(기초)별  성별     연령별      노인인구수      치매환자수  치매환자유병률  \
# 0      2020        전국        전국  전체  60~64세  3804709.5   23350.26     0.61
# 1      2020        전국        전국  전체  65~69세  2635592.0   36620.52     1.39
# 2      2020        전국        전국  전체  70~74세  2000708.5   77236.58     3.86
# 3      2020        전국        전국  전체  75~79세  1602662.5  189626.57    11.83
# 4      2020        전국        전국  전체  80~84세  1110911.5  232892.50    20.96
# ...     ...       ...       ...  ..     ...        ...        ...      ...
# 13735  2021   제주특별자치도      서귀포시   여  75~79세     3873.0     532.92    13.76
# 13736  2021   제주특별자치도      서귀포시   여  80~84세     3345.0     778.05    23.26
# 13737  2021   제주특별자치도      서귀포시   여   85세이상     3439.5    1134.00    32.97
# 13738  2021   제주특별자치도      서귀포시   여   60세이상    27760.0    2645.05     9.53
# 13739  2021   제주특별자치도      서귀포시   여   65세이상    20525.5    2637.09    12.85
#
#          최경도 환자     경도 환자  ...     중증 환자  알츠하이머 환자수  알츠하이머 환자유병률  혈관성치매 환자수  \
# 0       4062.95   9667.01  ...   3619.29       0.00         0.00   23350.26
# 1       6371.97  15160.90  ...   5676.18   34204.14         1.30       0.00
# 2      13439.16  31975.94  ...  11971.67   74101.52         3.70    1868.56
# 3      32995.02  78505.40  ...  29392.12   79081.82         4.93   36835.05
# 4      40523.30  96417.50  ...  36098.34  182257.11        16.41    8518.04
# ...         ...       ...  ...       ...        ...          ...        ...
# 13735     92.73    220.63  ...     82.60     247.48         6.39      32.15
# 13736    135.38    322.11  ...    120.60     704.12        21.05      11.71
# 13737    197.32    469.48  ...    175.77     973.03        28.29      78.42
# 13738    460.24   1095.05  ...    409.98    2111.89         7.61     130.23
# 13739    458.85   1091.76  ...    408.75    2111.89        10.29     122.27
#
#        혈관성치매 환자유병률  기타 환자환자수  기타 환자유병률  경도인지장애 환자수  경도인지장애 환자유병률          시도구별
# 0             0.61      0.00      0.00   568975.71         14.95            전국
# 1             0.00   2416.38      0.09   472079.05         17.91            전국
# 2             0.09   1279.71      0.06   432263.10         21.61            전국
# 3             2.30  73617.65      4.59   238681.35         14.89            전국
# 4             0.77  42047.60      3.78   530714.37         47.77            전국
# ...            ...       ...       ...         ...           ...           ...
# 13735         0.83    252.91      6.53      807.83         20.86  제주특별자치도 서귀포시
# 13736         0.35     61.88      1.85     1540.65         46.06  제주특별자치도 서귀포시
# 13737         2.28     82.20      2.39      799.73         23.25  제주특별자치도 서귀포시
# 13738         0.47    402.31      1.45     5688.87         20.49  제주특별자치도 서귀포시
# 13739         0.60    402.31      1.96     5371.43         26.17  제주특별자치도 서귀포시
#
# [13740 rows x 21 columns]

# %%
demen.columns
# Out:
# Index(['시점', '행정구역(시도)별', '행정구역(기초)별', '성별', '연령별', '노인인구수', '치매환자수',
#        '치매환자유병률', '최경도 환자', '경도 환자', '중등도 환자', '중증 환자', '알츠하이머 환자수',
#        '알츠하이머 환자유병률', '혈관성치매 환자수', '혈관성치매 환자유병률', '기타 환자환자수', '기타 환자유병률',
#        '경도인지장애 환자수', '경도인지장애 환자유병률', '시도구별'],
#       dtype='object')

# %%
demen.columns
# Out:
# Index(['시점', '행정구역(시도)별', '행정구역(기초)별', '성별', '연령별', '노인인구수', '치매환자수',
#        '치매환자유병률', '최경도 환자', '경도 환자', '중등도 환자', '중증 환자', '알츠하이머 환자수',
#        '알츠하이머 환자유병률', '혈관성치매 환자수', '혈관성치매 환자유병률', '기타 환자환자수', '기타 환자유병률',
#        '경도인지장애 환자수', '경도인지장애 환자유병률', '시도구별'],
#       dtype='object')

# %%
demen.dtypes
# Out:
# 시점                int64
# 행정구역(시도)별        object
# 행정구역(기초)별        object
# 성별               object
# 연령별              object
# 노인인구수           float64
# 치매환자수           float64
# 치매환자유병률         float64
# 최경도 환자          float64
# 경도 환자           float64
# 중등도 환자          float64
# 중증 환자           float64
# 알츠하이머 환자수       float64
# 알츠하이머 환자유병률     float64
# 혈관성치매 환자수       float64
# 혈관성치매 환자유병률     float64
# 기타 환자환자수        float64
# 기타 환자유병률        float64
# 경도인지장애 환자수      float64
# 경도인지장애 환자유병률    float64
# 시도구별             object
# dtype: object

# %%
num = []
for i in demen.columns:
    if i[-1] == '수','자'  :
        num.append(i)

# %%
num
# Out:
# ['시점',
#  '행정구역(시도)별',
#  '행정구역(기초)별',
#  '성별',
#  '연령별',
#  '노인인구수',
#  '치매환자수',
#  '치매환자유병률',
#  '최경도 환자',
#  '경도 환자',
#  '중등도 환자',
#  '중증 환자',
#  '알츠하이머 환자수',
#  '알츠하이머 환자유병률',
#  '혈관성치매 환자수',
#  '혈관성치매 환자유병률',
#  '기타 환자환자수',
#  '기타 환자유병률',
#  '경도인지장애 환자수',
#  '경도인지장애 환자유병률',
#  '시도구별']

# %%
len(demen)
# Out:
# 13740

# %%
demen[]

# %%
for i in num:
    if (i[-1] != '률') & (type(demen.dtypes) == 'float64') :
        (demen[i]*100).astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [123], in <cell line: 1>()
#       1 for i in num:
#       2     if (i[-1] != '률')  :
# ----> 3         demen[i].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1154, in astype_nansafe(arr, dtype, copy, skipna)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
# -> 1154         return lib.astype_intsafe(arr, dtype)
#    1156     # if we have a datetime/timedelta array of objects
#    1157     # then coerce to a proper dtype and recall astype_nansafe
#    1159     elif is_datetime64_dtype(dtype):
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:668, in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '전국'

# %%
demen.dtypes
# Out:
# 시점                int64
# 행정구역(시도)별        object
# 행정구역(기초)별        object
# 성별               object
# 연령별              object
# 노인인구수           float64
# 치매환자수           float64
# 치매환자유병률         float64
# 최경도 환자          float64
# 경도 환자           float64
# 중등도 환자          float64
# 중증 환자           float64
# 알츠하이머 환자수       float64
# 알츠하이머 환자유병률     float64
# 혈관성치매 환자수       float64
# 혈관성치매 환자유병률     float64
# 기타 환자환자수        float64
# 기타 환자유병률        float64
# 경도인지장애 환자수      float64
# 경도인지장애 환자유병률    float64
# 시도구별             object
# dtype: object
